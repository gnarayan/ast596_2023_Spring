# %%
import matplotlib.pyplot as plt
import pandas as pd
import h5py
import numpy as np
import scipy.stats as stats

# %%
sample_stats = pd.read_csv('sample_stats.csv')

# %%
plt.plot(sample_stats[sample_stats.idx==0].x,sample_stats[sample_stats.idx==0].y,'.',alpha=0.7)
np.mean(sample_stats[sample_stats.idx==0].x)
# Out:
# 54.26609978420493

# %%
plt.plot(sample_stats[sample_stats.idx==1].x,sample_stats[sample_stats.idx==1].y,'.',alpha=0.7)

# %%
plt.plot(sample_stats[sample_stats.idx==2].x,sample_stats[sample_stats.idx==2].y,'.',alpha=0.7)
np.mean(

# %%
plt.plot(sample_stats[sample_stats.idx==3].x,sample_stats[sample_stats.idx==3].y,'.',alpha=0.7)

# %%
plt.plot(sample_stats[sample_stats.idx==4].x,sample_stats[sample_stats.idx==4].y,'.',alpha=0.7)

# %%
plt.plot(sample_stats[sample_stats.idx==5].x,sample_stats[sample_stats.idx==5].y,'.',alpha=0.7)
np.mean(sample_stats[sample_stats.idx==5])
np.std(sample_stats[sample_stats.idx==5])
# Out:
# idx     0.000000
# x      16.708590
# y      26.835199
# dtype: float64

# %%
plt.plot(sample_stats[sample_stats.idx==6].x,sample_stats[sample_stats.idx==6].y,'.',alpha=0.7)

# %%
plt.plot(sample_stats[sample_stats.idx==7].x,sample_stats[sample_stats.idx==7].y,'.',alpha=0.7)

# %%
plt.plot(sample_stats[sample_stats.idx==8].x,sample_stats[sample_stats.idx==8].y,'.',alpha=0.7)

# %%
plt.plot(sample_stats[sample_stats.idx==9].x,sample_stats[sample_stats.idx==9].y,'.',alpha=0.7)

# %%
for i in range(9):
    print('idx '+str(i)+' Mean='+str(np.mean(sample_stats[sample_stats.idx==5])))
    print('idx '+str(i)+' Mean='+str(np.std(sample_stats[sample_stats.idx==5])))
# Out:
# idx 0 Mean=idx     5.000000
# x      54.260303
# y      47.839829
# dtype: float64
# idx 0 Mean=idx     0.000000
# x      16.708590
# y      26.835199
# dtype: float64
# idx 1 Mean=idx     5.000000
# x      54.260303
# y      47.839829
# dtype: float64
# idx 1 Mean=idx     0.000000
# x      16.708590
# y      26.835199
# dtype: float64
# idx 2 Mean=idx     5.000000
# x      54.260303
# y      47.839829
# dtype: float64
# idx 2 Mean=idx     0.000000
# x      16.708590
# y      26.835199
# dtype: float64
# idx 3 Mean=idx     5.000000
# x      54.260303
# y      47.839829
# dtype: float64
# idx 3 Mean=idx     0.000000
# x      16.708590
# y      26.835199
# dtype: float64
# idx 4 Mean=idx     5.000000
# x      54.260303
# y      47.839829
# dtype: float64
# idx 4 Mean=idx     0.000000
# x      16.708590
# y      26.835199
# dtype: float64
# idx 5 Mean=idx     5.000000
# x      54.260303
# y      47.839829
# dtype: float64
# idx 5 Mean=idx     0.000000
# x      16.708590
# ...
