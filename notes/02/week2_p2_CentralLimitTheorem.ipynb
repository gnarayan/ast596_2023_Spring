# %% [markdown]
# # ASTR596: Fundamentals of Data Science
# ## Week 2 In class exercise solutions - Part 2
# #### Gautham Narayan <gsn@illinois.edu>
#
# This notebook steps through the in class exercises during Week 2.
# You are not required to do things this way, and indeed by the end of the semester, you'll probably have your own favorite ways to do things. That's totally OK.

# %%
# we use the numpy scipy and friends stack so much that it's worth just having things in the namespace
# you can do that with %pylab here
# The things that start with % are called `magics`
# There's a lot of them, and you can see the list here: 
# https://ipython.readthedocs.io/en/stable/interactive/magics.html
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: <object object at 0x7f8d2f4c32e0>
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## The Central Limit Theorem
#
# There are several forms of the central limit theorem, but the one you encounter in the ICVG text book (Sec 3.4)
# https://en.wikipedia.org/wiki/Central_limit_theorem#Classical_CLT
#
# In our last exercise we saw that comparing the sample mean and variance isn't itself enough to assert that two distributions are the same, or can be approximated by a normal distribution with the corresponding mean and variance.
#
# The central limit theorem says that if you draw N identical and independently distributed (i.i.d) random variables from a distribution with some mean $\mu$ and standard deviation $\sigma$ and compute the sample mean of these random variables, *that sample mean itself is distributed as a normal distribution* $\text{Normal}(\mu, \sigma/\sqrt{N})$.
#
# This is kinda remarkable - we don't need to specify the details of the original distribution, just know that it has some *finite* mean and variance - but as long as we take lots of measurements, we'll be able to get an approximation of that mean with an accuracy that gets better as $\frac{1}{\sqrt{N}}$.
#
# We should verify this behavior and see where it breaks down.

# %%
import scipy.stats as st
from astropy.visualization import hist as ahist

# %%
# python lets you make lists of objects, including lists of functions themselves
# we'll try to verify the CLT behavior with three distributions

dists = [st.poisson, st.uniform, st.expon, st.cauchy]

# the poisson distribution needs a scale parameter specified
# the uniform distribution needs a range - we'll set it to have mean 0
# the others have sensible defaults of loc=0 and scale=1, so we'll leave them blank
dist_args = [[5,], [-0.5, 0.5], [], [] ]

# %%
# Now the CLT says that the accuracy gets better as a function of N
N = 3**np.arange(1, 7, 1)

# Finally, the CLT specifes that the mean itself is distributed as a Gaussian
# so taking one sample mean from N random variables isn't enough to see the behavior overall
# we will generate M samples of N variables
M = 100

# %%
# we'll visualize this with a 3x3 plot showing the behavior of each distrib
fig = figure(figsize=(18, 18))

# we'll also plot the variance as a function of N 
fig2 = figure(figsize(10, 5))
ax2 = fig2.add_subplot(121)
# we're going to separate the Cauchy distribution from the others 
# for reasons that will become apparent in a few seconds
ax3 = fig2.add_subplot(122)

for i, dist in enumerate(dists):
    dist_var = []
    for j, n in enumerate(N):
        
        args = dist_args[i]
        
        # we're simulating M samples of n random variables from each distribution
        means = np.array([dist.rvs(*args, size=n).mean() for i in range(M)])
        s_mean = means.mean()
        s_std  = means.std()
        dist_var.append(s_std)
        
        # lets plot the means of each distribution at this N
        plot_idx = len(N)*i + j + 1
        label=r'$\mu={:.2f} \, \sigma={:.2f}$'.format(s_mean, s_std)
        ax = fig.add_subplot(len(dists), len(N), plot_idx)
        
        # the default matplotlib histogram impelmentation is OK
        # astropy has a better one which allows automagic binning with a few algorithms
        # we'll use the Freedman-Diaconis rule
        # this sets the bin widths based on the inter-quartile range we talked about in class
        # and the sample size
        # https://en.wikipedia.org/wiki/Freedman%E2%80%93Diaconis_rule
        
        ahist(means, bins='freedman', ax=ax, color=f'C{i}', label=label)
        title = f'{dist.name}, N={n}'
        ax.set_title(title)
        ax.legend(frameon=False)
    if i == len(dists)-1:
        ax3.plot(N, dist_var, marker='o', color=f'C{i}', linestyle='--' , label=dist.name)  
    else:
        ax2.plot(N, dist_var, marker='o', color=f'C{i}', linestyle='--' , label=dist.name)
    ax2.set_xscale('log')
    ax3.set_xscale('log')
    ax2.legend()
    ax3.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Note that we're being sloppy and not even properly normalizing the weights of each of the sample means, but for this illustrative exercise it's fine.
#
# Also note that the Cauchy distribution doesn't behave as the CLT says it ought to. That's because the distribution is pathalogical and violates the CLT because it doesn't have a finite variance at all. Draws from the Cauchy distribution have too many outliers because of the probability density in the tails of the distribution.
#
# The thing to remember is that real life often has outliers as well! We *assume* Gaussianity, but it's worth checking if that assumption actually helps describe our data. We'll do that in our next and last exercise for week 2.

# %%
# !conda install -y tensorflow
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/gnarayan/miniconda3/envs/yse
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     abseil-cpp-20210324.2      |       h23ab428_0         866 KB
#     absl-py-1.3.0              |   py39hecd8cb5_0         168 KB
#     aiohttp-3.8.3              |   py39h6c40b1e_0         428 KB
#     aiosignal-1.2.0            |     pyhd3eb1b0_0          12 KB
#     astunparse-1.6.3           |             py_0          17 KB
#     async-timeout-4.0.2        |   py39hecd8cb5_0          13 KB
#     blinker-1.4                |   py39hecd8cb5_0          23 KB
#     cachetools-4.2.2           |     pyhd3eb1b0_0          13 KB
#     dataclasses-0.8            |     pyh6d0b6a4_7           8 KB
#     frozenlist-1.3.3           |   py39h6c40b1e_0          41 KB
#     gast-0.3.3                 |             py_0          14 KB
#     google-auth-2.6.0          |     pyhd3eb1b0_0          83 KB
#     google-auth-oauthlib-0.5.2 |   py39hecd8cb5_0          26 KB
#     google-pasta-0.2.0         |     pyhd3eb1b0_0          46 KB
#     grpc-cpp-1.37.1            |       h69eed7d_3         2.8 MB  conda-forge
#     grpcio-1.37.1              |   py39hb974310_0         2.0 MB  conda-forge
#     h5py-2.10.0                |   py39h90fc2a2_0         796 KB
#     icu-68.1                   |       h23ab428_0        11.3 MB
#     keras-preprocessing-1.1.2  |     pyhd3eb1b0_0          35 KB
#     libclang-11.1.0            |default_he082bbe_1        14.4 MB  conda-forge
#     libllvm11-11.1.0           |       h46f1229_6        17.7 MB
#     libpq-12.9                 |       h1c9f633_3         2.0 MB
#     libprotobuf-3.15.8         |       hcf210ce_1         2.2 MB  conda-forge
#     libxml2-2.9.12             |       h93ec3fd_0         685 KB  conda-forge
#     markdown-3.4.1             |   py39hecd8cb5_0         130 KB
#     multidict-6.0.2            |   py39hca72f7f_0          45 KB
#     mysql-common-8.0.25        |       h694c41f_0         1.5 MB  conda-forge
#     mysql-libs-8.0.25          |       h54f5a68_0         1.7 MB  conda-forge
#     nspr-4.33                  |       he9d5cce_0         228 KB
#     nss-3.74                   |       h47edf6a_0         1.8 MB
#     oauthlib-3.2.1             |   py39hecd8cb5_0         194 KB
#     opt_einsum-3.3.0           |     pyhd3eb1b0_1          57 KB
#     protobuf-3.15.8            |   py39h9fcab8e_0         317 KB  conda-forge
#     pyasn1-0.4.8               |     pyhd3eb1b0_0          54 KB
#     pyasn1-modules-0.2.8       |             py_0          72 KB
#     pyjwt-2.4.0                |   py39hecd8cb5_0          35 KB
#     pyqt-5.12.3                |   py39h6e9494a_8          22 KB  conda-forge
#     pyqt-impl-5.12.3           |   py39he44290a_8         4.7 MB  conda-forge
#     pyqt5-sip-4.19.18          |   py39h15fb055_8         275 KB  conda-forge
#     pyqtchart-5.12             |   py39he44290a_8         213 KB  conda-forge
#     pyqtwebengine-5.12.1       |   py39he44290a_8         140 KB  conda-forge
#     python-flatbuffers-1.12    |     pyhd3eb1b0_0          24 KB
#     qt-5.12.9                  |       h126340a_2        87.8 MB  conda-forge
#     re2-2021.08.01             |       he49afe7_0         193 KB  conda-forge
#     requests-oauthlib-1.3.0    |             py_0          23 KB
#     rsa-4.7.2                  |     pyhd3eb1b0_1          28 KB
#     tensorboard-2.4.0          |     pyhc547734_0         8.8 MB
#     tensorboard-plugin-wit-1.6.0|             py_0         630 KB
#     tensorflow-2.4.1           |   py39h6e9494a_0          25 KB  conda-forge
#     tensorflow-base-2.4.1      |   py39h9e0eb93_0       116.3 MB  conda-forge
#     tensorflow-estimator-2.4.1 |     pyheb71bc4_0         260 KB
#     termcolor-2.1.0            |   py39hecd8cb5_0          12 KB
#     werkzeug-2.0.3             |     pyhd3eb1b0_0         221 KB
#     yarl-1.8.1                 |   py39hca72f7f_0          82 KB
#     ------------------------------------------------------------
#                                            Total:       281.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   abseil-cpp         pkgs/main/osx-64::abseil-cpp-20210324.2-h23ab428_0
#   absl-py            pkgs/main/osx-64::absl-py-1.3.0-py39hecd8cb5_0
#   aiohttp            pkgs/main/osx-64::aiohttp-3.8.3-py39h6c40b1e_0
#   aiosignal          pkgs/main/noarch::aiosignal-1.2.0-pyhd3eb1b0_0
#   astunparse         pkgs/main/noarch::astunparse-1.6.3-py_0
#   async-timeout      pkgs/main/osx-64::async-timeout-4.0.2-py39hecd8cb5_0
#   blinker            pkgs/main/osx-64::blinker-1.4-py39hecd8cb5_0
#   cachetools         pkgs/main/noarch::cachetools-4.2.2-pyhd3eb1b0_0
#   dataclasses        pkgs/main/noarch::dataclasses-0.8-pyh6d0b6a4_7
#   dbus               pkgs/main/osx-64::dbus-1.13.18-h18a8e69_0
#   frozenlist         pkgs/main/osx-64::frozenlist-1.3.3-py39h6c40b1e_0
#   gast               pkgs/main/noarch::gast-0.3.3-py_0
#   glib               pkgs/main/osx-64::glib-2.69.1-h8346a28_1
#   google-auth        pkgs/main/noarch::google-auth-2.6.0-pyhd3eb1b0_0
#   google-auth-oauth~ pkgs/main/osx-64::google-auth-oauthlib-0.5.2-py39hecd8cb5_0
#   google-pasta       pkgs/main/noarch::google-pasta-0.2.0-pyhd3eb1b0_0
#   grpc-cpp           conda-forge/osx-64::grpc-cpp-1.37.1-h69eed7d_3
#   grpcio             conda-forge/osx-64::grpcio-1.37.1-py39hb974310_0
#   keras-preprocessi~ pkgs/main/noarch::keras-preprocessing-1.1.2-pyhd3eb1b0_0
#   libclang           conda-forge/osx-64::libclang-11.1.0-default_he082bbe_1
#   libllvm11          pkgs/main/osx-64::libllvm11-11.1.0-h46f1229_6
#   libpq              pkgs/main/osx-64::libpq-12.9-h1c9f633_3
#   libprotobuf        conda-forge/osx-64::libprotobuf-3.15.8-hcf210ce_1
#   markdown           pkgs/main/osx-64::markdown-3.4.1-py39hecd8cb5_0
#   multidict          pkgs/main/osx-64::multidict-6.0.2-py39hca72f7f_0
#   mysql-common       conda-forge/osx-64::mysql-common-8.0.25-h694c41f_0
#   mysql-libs         conda-forge/osx-64::mysql-libs-8.0.25-h54f5a68_0
#   nspr               pkgs/main/osx-64::nspr-4.33-he9d5cce_0
#   nss                pkgs/main/osx-64::nss-3.74-h47edf6a_0
#   oauthlib           pkgs/main/osx-64::oauthlib-3.2.1-py39hecd8cb5_0
#   opt_einsum         pkgs/main/noarch::opt_einsum-3.3.0-pyhd3eb1b0_1
#   pcre               pkgs/main/osx-64::pcre-8.45-h23ab428_0
#   protobuf           conda-forge/osx-64::protobuf-3.15.8-py39h9fcab8e_0
#   pyasn1             pkgs/main/noarch::pyasn1-0.4.8-pyhd3eb1b0_0
#   pyasn1-modules     pkgs/main/noarch::pyasn1-modules-0.2.8-py_0
#   pyjwt              pkgs/main/osx-64::pyjwt-2.4.0-py39hecd8cb5_0
#   pyqt-impl          conda-forge/osx-64::pyqt-impl-5.12.3-py39he44290a_8
#   pyqt5-sip          conda-forge/osx-64::pyqt5-sip-4.19.18-py39h15fb055_8
#   pyqtchart          conda-forge/osx-64::pyqtchart-5.12-py39he44290a_8
#   pyqtwebengine      conda-forge/osx-64::pyqtwebengine-5.12.1-py39he44290a_8
#   python-flatbuffers pkgs/main/noarch::python-flatbuffers-1.12-pyhd3eb1b0_0
#   re2                conda-forge/osx-64::re2-2021.08.01-he49afe7_0
#   requests-oauthlib  pkgs/main/noarch::requests-oauthlib-1.3.0-py_0
#   rsa                pkgs/main/noarch::rsa-4.7.2-pyhd3eb1b0_1
#   tensorboard        pkgs/main/noarch::tensorboard-2.4.0-pyhc547734_0
#   tensorboard-plugi~ pkgs/main/noarch::tensorboard-plugin-wit-1.6.0-py_0
#   tensorflow         conda-forge/osx-64::tensorflow-2.4.1-py39h6e9494a_0
#   tensorflow-base    conda-forge/osx-64::tensorflow-base-2.4.1-py39h9e0eb93_0
#   tensorflow-estima~ pkgs/main/noarch::tensorflow-estimator-2.4.1-pyheb71bc4_0
#   termcolor          pkgs/main/osx-64::termcolor-2.1.0-py39hecd8cb5_0
#   werkzeug           pkgs/main/noarch::werkzeug-2.0.3-pyhd3eb1b0_0
#   yarl               pkgs/main/osx-64::yarl-1.8.1-py39hca72f7f_0
#
# The following packages will be UPDATED:
#
#   icu                                       58.2-h0a44026_3 --> 68.1-h23ab428_0
#   pyqt                 pkgs/main::pyqt-5.9.2-py39h23ab428_6 --> conda-forge::pyqt-5.12.3-py39h6e9494a_8
#   qt                         pkgs/main::qt-5.9.7-h468cd18_1 --> conda-forge::qt-5.12.9-h126340a_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   libxml2              pkgs/main::libxml2-2.9.14-hbf8cd5e_0 --> conda-forge::libxml2-2.9.12-h93ec3fd_0
#
# The following packages will be DOWNGRADED:
#
#   h5py                                 3.7.0-py39h4a1dd59_0 --> 2.10.0-py39h90fc2a2_0
#
#
#
# Downloading and Extracting Packages
# grpcio-1.37.1        | 2.0 MB    |                                       |   0%
# google-auth-oauthlib | 26 KB     |                                       |   0%
#
# astunparse-1.6.3     | 17 KB     |                                       |   0%
#
#
# abseil-cpp-20210324. | 866 KB    |                                       |   0%
#
#
#
# aiohttp-3.8.3        | 428 KB    |                                       |   0%
#
#
#
#
# tensorboard-2.4.0    | 8.8 MB    |                                       |   0%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   |                                       |   0%
#
#
#
#
#
#
# blinker-1.4          | 23 KB     |                                       |   0%
#
#
#
#
#
#
#
# aiosignal-1.2.0      | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# pyasn1-modules-0.2.8 | 72 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# re2-2021.08.01       | 193 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# gast-0.3.3           | 14 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.74             | 1.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# absl-py-1.3.0        | 168 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.12.3          | 22 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rsa-4.7.2            | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# async-timeout-4.0.2  | 13 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-2.10.0          | 796 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-flatbuffers-1 | 24 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.15.8   | 2.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cachetools-4.2.2     | 13 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# multidict-6.0.2      | 45 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# aiohttp-3.8.3        | 428 KB    | #3                                    |   4%
#
# astunparse-1.6.3     | 17 KB     | ###################################1  |  95%
#
#
# abseil-cpp-20210324. | 866 KB    | 6                                     |   2%
#
#
#
#
# tensorboard-2.4.0    | 8.8 MB    |                                       |   0%
#
#
#
#
#
# grpcio-1.37.1        | 2.0 MB    | 2                                     |   1%
#
# astunparse-1.6.3     | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
# blinker-1.4          | 23 KB     | ##########################1           |  71%
#
#
#
#
# tensorboard-2.4.0    | 8.8 MB    | ###8                                  |  11%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ##2                                   |   6%
# google-auth-oauthlib | 26 KB     | ######################8               |  62%
#
#
#
#
#
#
#
# grpcio-1.37.1        | 2.0 MB    | ######################4               |  61%
#
#
#
#
#
#
#
#
# pyasn1-modules-0.2.8 | 72 KB     | ########2                             |  22%
#
#
#
#
# tensorboard-2.4.0    | 8.8 MB    | ######8                               |  19%
#
#
#
#
#
#
#
#
#
#
# gast-0.3.3           | 14 KB     | ##################################### | 100%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ###6                                  |  10%
#
#
#
#
#
#
# blinker-1.4          | 23 KB     | ##################################### | 100%
#
#
#
#
# tensorboard-2.4.0    | 8.8 MB    | ###########6                          |  32%
#
#
#
#
#
#
#
#
#
# re2-2021.08.01       | 193 KB    | ###                                   |   8%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | #####7                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.74             | 1.8 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
# absl-py-1.3.0        | 168 KB    | ###5                                  |  10%
#
#
#
#
# tensorboard-2.4.0    | 8.8 MB    | ##################6                   |  50%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | #########3                            |  25%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.74             | 1.8 MB    | #####################5                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.12.3          | 22 KB     | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rsa-4.7.2            | 28 KB     | #####################2                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# async-timeout-4.0.2  | 13 KB     | ##################################### | 100%
#
#
#
#
# tensorboard-2.4.0    | 8.8 MB    | #######################3              |  63%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ###########6                          |  31%
# google-auth-oauthlib | 26 KB     | ##################################### | 100%
# google-auth-oauthlib | 26 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-flatbuffers-1 | 24 KB     | ########################9             |  68%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   |                                       |   0%
#
#
#
#
# tensorboard-2.4.0    | 8.8 MB    | ############################7         |  78%
#
#
#
#
#
#
#
# aiosignal-1.2.0      | 12 KB     | ##################################### | 100%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.15.8   | 2.2 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | 8                                     |   2%
#
#
#
#
# tensorboard-2.4.0    | 8.8 MB    | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-2.10.0          | 796 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.15.8   | 2.2 MB    | ####################4                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cachetools-4.2.2     | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #4                                    |   4%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | #################2                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.15.8   | 2.2 MB    | ####################################7 |  99%
#
#
#
# aiohttp-3.8.3        | 428 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# multidict-6.0.2      | 45 KB     | #############2                        |  36%
#
#
#
# aiohttp-3.8.3        | 428 KB    | ##################################### | 100%
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #9                                    |   5%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ####################                  |  54%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##4                                   |   7%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ########################5             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##8                                   |   8%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ###3                                  |   9%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | #############################         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ####3                                 |  12%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ################################7     |  89%
#
#
#
#
#
#
#
#
# pyasn1-modules-0.2.8 | 72 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ####9                                 |  13%
#
#
#
#
#
#
#
#
# pyasn1-modules-0.2.8 | 72 KB     | ##################################### | 100%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
# gast-0.3.3           | 14 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ######8                               |  19%
#
#
#
#
#
#
#
#
#
# re2-2021.08.01       | 193 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# re2-2021.08.01       | 193 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #######4                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #######9                              |  22%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ########4                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #########7                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
# absl-py-1.3.0        | 168 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# absl-py-1.3.0        | 168 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##########2                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##########7                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.12.3          | 22 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyqt-5.12.3          | 22 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #############1                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #############8                        |  37%
#
#
# abseil-cpp-20210324. | 866 KB    | ##################################### | 100%
#
#
# abseil-cpp-20210324. | 866 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##############4                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rsa-4.7.2            | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# rsa-4.7.2            | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# async-timeout-4.0.2  | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ################4                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-flatbuffers-1 | 24 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #################3                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-flatbuffers-1 | 24 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #################9                    |  49%
#
#
#
#
#
#
#
#
#
#
#
#
# grpcio-1.37.1        | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ###################                   |  52%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ###################7                  |  54%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.74             | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# nss-3.74             | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ####################3                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #####################2                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cachetools-4.2.2     | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-2.10.0          | 796 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# h5py-2.10.0          | 796 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #######################1              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #######################7              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ########################7             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# multidict-6.0.2      | 45 KB     | ##################################### | 100%
# multidict-6.0.2      | 45 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #########################4            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##########################1           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##########################8           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ############################2         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ############################9         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##############################9       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | #################################5    |  91%
#
#
#
#
# tensorboard-2.4.0    | 8.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##################################8   |  94%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libprotobuf-3.15.8   | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
# libllvm11-11.1.0     | 17.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# qt-5.12.9            | 87.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
